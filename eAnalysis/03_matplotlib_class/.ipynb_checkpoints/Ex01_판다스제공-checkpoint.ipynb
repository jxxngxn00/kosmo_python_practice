# %% [markdown]
# ### 1. Series 의 plot()

# %%
# %matplotlib inline

# %%
from pandas import Series

# %%
# 판다스 그래프 : Series의 plot() 
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])

s.plot(kind='bar');

# %%
# 간단한 한글화
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %%
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])

splot = s.plot(kind='bar');
splot.set_xlabel('데이터')
splot.set_ylabel('값')
splot.set_title('샘플 데이터')
# Out:
# Text(0.5, 1.0, '샘플 데이터')

# %% [markdown]
# ## 2. DataFrame 그래프

# %%
from pandas import DataFrame
import numpy as np

# 데이타프레임에서 시각화 작업
df=DataFrame(np.random.randn(10, 4),    # 난수 10개를 4번
             columns=['level','step','cnt','temp'], 
             index=np.arange(0,100,10))     # np.arange(0,100,10)
df
# Out:
#        level      step       cnt      temp
# 0   0.775404  1.488610 -0.454562  1.010218
# 10  0.211555  2.726487 -1.145454 -0.523588
# 20  0.354108 -1.129122  0.449277  0.015359
# 30 -0.937561 -0.300596  0.487333 -1.946006
# 40  0.722091  0.577925 -0.376567  1.138759
# 50 -0.229074  0.159858  1.385461 -0.502128
# 60  0.700612 -0.635667  0.362316  0.118081
# 70  0.050020 -0.407596  0.047258 -1.194201
# 80  0.524825  0.591133 -0.208621  0.429126
# 90  0.139522  0.152137 -0.368469  1.730029

# %%
df.plot();

# %%
# df.plot(kind='bar');  수직 바차트
# df.plot(kind='barh'); 수평 바차트

# %% [markdown]
# [참고] 데이타사이언스스쿨 > Pandas의 시각화 기능
#
# https://datascienceschool.net/view-notebook/372443a5d90a46429c6459bba8b4342c/
